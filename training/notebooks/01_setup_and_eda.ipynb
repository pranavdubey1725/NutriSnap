# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("⚠️ No GPU detected! Go to Runtime → Change runtime type → T4 GPU")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU name: Tesla T4
# GPU memory: 15.6 GB

# %%
# Core ML
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import Food101

# Visualization
import matplotlib.pyplot as plt
import numpy as np

# Utilities
import os
from collections import Counter

print(f"torchvision version: {torchvision.__version__}")
print("✅ All imports successful")
# Out:
# torchvision version: 0.25.0+cu128
# ✅ All imports successful

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

##In PyTorch, data and models need to be on the same device (CPU or GPU). Throughout the project, whenever we create a tensor or load a model, we'll do .to(device). By defining it once here, if you ever run this on a machine without a GPU, everything automatically falls back to CPU without changing any other code.
# Out:
# Using device: cuda
